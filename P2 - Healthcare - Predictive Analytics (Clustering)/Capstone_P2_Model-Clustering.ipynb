# %% [markdown]
# <table class="table table-bordered">
#     <tr>
#         <th style="text-align:center; width:35%"><img src='https://mma.prnewswire.com/media/1860917/NTUC_LHUB_Logo.jpg' style="width: 350px; height: 125px; "></th>
#         <th style="text-align:center;"><h1>Project 2 - Healthcare - Predictive Analytics</h1><h2>A Data Analysis - Building Models  </h2><h3></h3></th>
#     </tr>
# </table>

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load data
cardio_df = pd.read_csv('cardio_cleaned_Cluster.csv')

# %%
cardio_df.head(1)
# Out:
#    clusters  active  alco  cholesterol  gluc  smoke  disease  ap_pulse  \
# 0         4       1     0            0     0      0        0         1
#
#    ap_map  BMI  age_group
# 0       2    1          4

# %%
x = cardio_df.drop('disease', axis=1)
y = cardio_df['disease']

# %%
x.head(5)
# Out:
#    clusters  active  alco  cholesterol  gluc  smoke  ap_pulse  ap_map  BMI  \
# 0         4       1     0            0     0      0         1       2    1
# 1         2       1     0            2     0      0         2       4    3
# 2         0       0     0            2     0      0         3       2    1
# 3         0       1     0            0     0      0         2       5    2
# 4         3       0     0            0     0      0         2       0    1
#
#    age_group
# 0          4
# 1          5
# 2          4
# 3          3
# 4          3

# %%
y.head(5)
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: disease, dtype: int64

# %% [markdown]
# # Spliting data

# %%
from sklearn.model_selection import train_test_split

# %%
# The dataset will be split into 70% training, 30% testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# # Scaling data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # Build Baseline Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
SEED = 42

# %%
lg_baseline = LogisticRegression(random_state=SEED)

# %%
lg_baseline.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %% [markdown]
# # Evaluate Model Performance with Cross-validation

# %%
from sklearn.model_selection import cross_validate, KFold

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)

# %%
# Access various information including fit times and predict times
cv_results = cross_validate(lg_baseline, x_train, y_train, cv=kfold, scoring=['accuracy'], return_train_score=True, n_jobs=-1)

# %%
print("Training Score:", cv_results['train_accuracy'].mean())
print("Test Score:", cv_results['test_accuracy'].mean())
print("Fit Time:", cv_results['fit_time'].mean(), 'seconds')
print("Predict Time:", cv_results['score_time'].mean(), 'seconds')
# Out:
# Training Score: 0.8304650899624575
# Test Score: 0.8302809757027919
# Fit Time: 0.11822562217712403 seconds
# Predict Time: 0.0039996147155761715 seconds

# %% [markdown]
# <font color="blue">Baseline model gives a good accuracy.

# %% [markdown]
# # Build Other Models

# %%
#KNN Classification
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
#Support Vector Machine
from sklearn.svm import SVC
svc = SVC(random_state=SEED)
svc.fit(x_train,y_train)
# Out:
# SVC(random_state=42)

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=SEED)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#naive bayes (Gaussian)
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
#naive bayes (multinomial)
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()
mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
#Ramdom Forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=SEED)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
cv_results = cross_validate(rf, x_train, y_train, cv=kfold, scoring=['accuracy'], return_train_score=True, n_jobs=-1)

# %%
print("Training Score:", cv_results['train_accuracy'].mean())
print("Test Score:", cv_results['test_accuracy'].mean())
print("Fit Time:", cv_results['fit_time'].mean(), 'seconds')
print("Predict Time:", cv_results['score_time'].mean(), 'seconds')
# Out:
# Training Score: 0.9386268075237931
# Test Score: 0.9241074862057008
# Fit Time: 4.949205923080444 seconds
# Predict Time: 0.32960782051086424 seconds

# %%
#Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(random_state=SEED)
gb.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
#XGBoost
from xgboost import XGBClassifier
xgb = XGBClassifier(random_state=SEED)
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
#lightgbm
from lightgbm import LGBMClassfier
lgbm = lightgbm.LGBMClassifier()
lgbm.fit(x_train,y_train)
# Out:
# [LightGBM] [Info] Number of positive: 20554, number of negative: 21545
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002465 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 42
# [LightGBM] [Info] Number of data points in the train set: 42099, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.488230 -> initscore=-0.047088
# [LightGBM] [Info] Start training from score -0.047088
# LGBMClassifier()

# %% [markdown]
# # Model Performance Summary

# %%
models = [lg_baseline, KNN, svc, dt, gnb, mnb, rf, gb, xgb, lgbm]
model_names = [type(model).__name__ for model in models]
result_table = pd.DataFrame(columns=['Model','Training Accuracy','Test Accuracy','Fit Time (seconds)','Predict Time (seconds)','Total time taken (seconds)'])

for model, m_name in zip(models, model_names):
    cv_results = cross_validate(model, x_train, y_train, cv=kfold, scoring=['accuracy'], return_train_score=True, n_jobs=-1)
    train_accu = cv_results['train_accuracy'].mean()
    test_accu = cv_results['test_accuracy'].mean()
    fit = cv_results['fit_time'].mean()
    pred = cv_results['score_time'].mean()
    total = fit + pred
    result_table = pd.concat([result_table,pd.DataFrame({'Model':[m_name], 'Training Accuracy':[train_accu],
                                                         'Test Accuracy':[test_accu],'Fit Time (seconds)':[fit], 'Predict Time (seconds)':[pred],
                                                        'Total time taken (seconds)':[total]})],ignore_index=True)

# %%
result_table_sorted = result_table.sort_values(by='Test Accuracy', ascending = False)
display(result_table_sorted)
# Out:
#                         Model  Training Accuracy  Test Accuracy  \
# 9              LGBMClassifier           0.931156       0.926364
# 7  GradientBoostingClassifier           0.926542       0.926008
# 8               XGBClassifier           0.933383       0.925271
# 6      RandomForestClassifier           0.938627       0.924107
# 3      DecisionTreeClassifier           0.938645       0.920164
# 1        KNeighborsClassifier           0.918632       0.906387
# 2                         SVC           0.889433       0.888548
# 0          LogisticRegression           0.830465       0.830281
# 5               MultinomialNB           0.813238       0.813060
# 4                  GaussianNB           0.753242       0.753557
#
#    Fit Time (seconds)  Predict Time (seconds)  Total time taken (seconds)
# 9            1.658101                0.061604                    1.719705
# 7            7.374176                0.055314                    7.429489
# 8            1.007704                0.086630                    1.094334
# 6            4.497773                0.311843                    4.809616
# 3            0.061603                0.004401                    0.066004
# 1            0.347224                8.816410                    9.163634
# 2          103.782261               30.611834                  134.394095
# 0            0.175522                0.006104                    0.181626
# 5            0.033601                0.004200                    0.037801
# 4            0.032805                0.007200                    0.040005

# %%
plt.subplot(1,2,1)
plt.barh(width=result_table_sorted['Test Accuracy'],y=result_table_sorted['Model'], alpha=0.3, height=0.3, label='Test Accuracy')
plt.barh(width=result_table_sorted['Training Accuracy'],y=result_table_sorted['Model'],align='edge', alpha=0.3, height=0.3, label='Training Accuracy')
plt.legend(loc='upper left')
plt.xlabel('Accuracy - higher is better')
plt.subplot(1,2,2)
plt.plot(result_table_sorted['Fit Time (seconds)'],result_table_sorted['Model'], marker='o', label='Fit Time')
plt.plot(result_table_sorted['Predict Time (seconds)'],result_table_sorted['Model'], marker='x', label='Predict Time')
plt.legend()
plt.xlabel('Time - lower is better')
plt.subplots_adjust(wspace=0.5, right=2)
plt.show()

# %% [markdown]
# <font color="blue">We observed that by using model default parameters, models under Gradient Boosting (GradientBoostingClassifier, LGBMClassifier, XGBClassifier) generally give 92% test accuracy and above. As all three of them give similar accuracy, we will choose XGBClassifier with comparable lower computational cost.
#
# <font color="blue">Both RandomForestClassifier and DecisionTreeCLassifier also give accuracy above 92%. We will try if we can improve further the accuracy.
#
# <font color="blue">SVC has test accuracy of 89%. However, the time taken for training and predicting is at least 10 times more than other models, causing high computational cost. Since there are more efficient models available, we will drop this model.
#
# <font color="blue">Multinomial Naive Bayes gives very low accuracy while there is no parameters that we can tune for Gaussian Naive Bayes to further improve accuracy. Therefore we will drop these two models.

# %% [markdown]
# <font color="blue">We will select XGBClassifier, Logistic Regression, Decision Tree, Random Forest, and K-NearestNeighbours for Hyperparameter Optimization

# %% [markdown]
# # Hyperparameters Optimization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# Define the classifiers
classifiers = {
    'XGBClassifier': XGBClassifier(random_state=SEED),
    'LogisticRegression': LogisticRegression(random_state=SEED),
    'DecisionTreeClassifier': DecisionTreeClassifier(random_state=SEED),
    'RandomForestClassifier': RandomForestClassifier(random_state=SEED),
    'KNeighborsClassifier': KNeighborsClassifier()
}

# Define the parameter grids for each classifier
param_grids = {
    'XGBClassifier': {'classifier__max_depth': [3, 5, 7], 'classifier__learning_rate': [0.1, 0.01, 0.05],
                     'classifier__n_estimators': [100,200,300], 'classifier__min_child_weight': [1,3,5],
                     'classifier__gamma': [0.0, 0.1, 0.2], 'classifier__subsample': [0.8,0.9,1.0],
                     'classifier__colsample_bytree': [0.8,0.9,1.0]},
    'LogisticRegression': {'classifier__C': [1, 10, 20], 'classifier__solver': ['lbfgs', 'liblinear']},
    'DecisionTreeClassifier': {'classifier__max_depth': [3, 5, 25], 'classifier__max_leaf_nodes': [10,20,100]},
    'RandomForestClassifier': {'classifier__n_estimators': [100,300,500], 'classifier__max_depth': [3, 10, 50], 'classifier__max_leaf_nodes': [20,100,250]},
    'KNeighborsClassifier': {'classifier__n_neighbors': [5, 30, 50], 'classifier__weights': ['uniform','distance']}
}

# Create pipelines for each classifier
pipelines = {name: Pipeline([('classifier', clf)]) for name, clf in classifiers.items()}

# Perform grid search for each classifier
results = {}
for name, pipeline in pipelines.items():
    grid_search = GridSearchCV(pipeline, param_grids[name], cv=5, scoring='accuracy', n_jobs=-1)
    grid_search.fit(x_train, y_train)
    results[name] = {
        'best_params': grid_search.best_params_,
        'best_score': grid_search.best_score_,
        'cv_results': grid_search.cv_results_
    }

# %%
results
# Out:
# {'XGBClassifier': {'best_params': {'classifier__colsample_bytree': 0.9,
#    'classifier__gamma': 0.0,
#    'classifier__learning_rate': 0.1,
#    'classifier__max_depth': 3,
#    'classifier__min_child_weight': 1,
#    'classifier__n_estimators': 200,
#    'classifier__subsample': 0.9},
#   'best_score': 0.9275279335086145,
#   'cv_results': {'mean_fit_time': array([0.81068554, 0.76952114, 0.49998441, ..., 5.03181186, 5.17304368,
#           2.75529361]),
#    'std_fit_time': array([0.03837279, 0.03534714, 0.02378394, ..., 0.41711916, 0.45685403,
#           0.05555586]),
#    'mean_score_time': array([0.03280315, 0.03320136, 0.02260156, ..., 0.29806323, 0.27097306,
#           0.15116353]),
#    'std_score_time': array([0.01096385, 0.01419033, 0.00349638, ..., 0.05154024, 0.06858818,
#           0.02248787]),
#    'param_classifier__colsample_bytree': masked_array(data=[0.8, 0.8, 0.8, ..., 1.0, 1.0, 1.0],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__gamma': masked_array(data=[0.0, 0.0, 0.0, ..., 0.2, 0.2, 0.2],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__learning_rate': masked_array(data=[0.1, 0.1, 0.1, ..., 0.05, 0.05, 0.05],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__max_depth': masked_array(data=[3, 3, 3, ..., 7, 7, 7],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__min_child_weight': masked_array(data=[1, 1, 1, ..., 5, 5, 5],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__n_estimators': masked_array(data=[100, 100, 100, ..., 300, 300, 300],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__subsample': masked_array(data=[0.8, 0.9, 1.0, ..., 0.8, 0.9, 1.0],
#                 mask=[False, False, False, ..., False, False, False],
#           fill_value='?',
#                dtype=object),
#    'params': [{'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.1,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 5,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.01,
#      'classifier__max_depth': 7,
#      'classifier__min_child_weight': 5,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 1,
#      'classifier__n_estimators': 300,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 0.9},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 100,
#      'classifier__subsample': 1.0},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.8},
#     {'classifier__colsample_bytree': 0.8,
#      'classifier__gamma': 0.0,
#      'classifier__learning_rate': 0.05,
#      'classifier__max_depth': 3,
#      'classifier__min_child_weight': 3,
#      'classifier__n_estimators': 200,
#      'classifier__subsample': 0.9},
# ...
#     {'classifier__C': 10, 'classifier__solver': 'lbfgs'},
#     {'classifier__C': 10, 'classifier__solver': 'liblinear'},
#     {'classifier__C': 20, 'classifier__solver': 'lbfgs'},
#     {'classifier__C': 20, 'classifier__solver': 'liblinear'}],
#    'split0_test_score': array([0.82470309, 0.82458432, 0.82494062, 0.82494062, 0.82494062,
#           0.82494062]),
#    'split1_test_score': array([0.83135392, 0.83135392, 0.83159145, 0.83159145, 0.83159145,
#           0.83159145]),
#    'split2_test_score': array([0.83028504, 0.83028504, 0.83004751, 0.83004751, 0.83004751,
#           0.83004751]),
#    'split3_test_score': array([0.83669834, 0.83669834, 0.83657957, 0.83657957, 0.83657957,
#           0.83657957]),
#    'split4_test_score': array([0.82765174, 0.82765174, 0.82741418, 0.82741418, 0.82741418,
#           0.82741418]),
#    'mean_test_score': array([0.83013842, 0.83011467, 0.83011467, 0.83011467, 0.83011467,
#           0.83011467]),
#    'std_test_score': array([0.00400644, 0.00403882, 0.00395079, 0.00395079, 0.00395079,
#           0.00395079]),
#    'rank_test_score': array([1, 2, 3, 3, 3, 3])}},
#  'DecisionTreeClassifier': {'best_params': {'classifier__max_depth': 25,
#    'classifier__max_leaf_nodes': 100},
#   'best_score': 0.9255801646485061,
#   'cv_results': {'mean_fit_time': array([0.10312676, 0.09062476, 0.09999781, 0.11607385, 0.1276824 ,
#           0.13217974, 0.11706238, 0.12499971, 0.13265219]),
#    'std_fit_time': array([0.00765395, 0.01169249, 0.01249788, 0.016225  , 0.01721747,
#           0.01977592, 0.01008464, 0.01976491, 0.00812481]),
#    'mean_score_time': array([0.00624914, 0.018752  , 0.00625062, 0.00354519, 0.00393395,
#           0.01562743, 0.01249847, 0.00312514, 0.00409193]),
#    'std_score_time': array([0.0076536 , 0.01530764, 0.00765542, 0.0060969 , 0.00786791,
#           0.00988129, 0.01169221, 0.00625029, 0.00703743]),
#    'param_classifier__max_depth': masked_array(data=[3, 3, 3, 5, 5, 5, 25, 25, 25],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__max_leaf_nodes': masked_array(data=[10, 20, 100, 10, 20, 100, 10, 20, 100],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False],
#           fill_value='?',
#                dtype=object),
#    'params': [{'classifier__max_depth': 3, 'classifier__max_leaf_nodes': 10},
#     {'classifier__max_depth': 3, 'classifier__max_leaf_nodes': 20},
#     {'classifier__max_depth': 3, 'classifier__max_leaf_nodes': 100},
#     {'classifier__max_depth': 5, 'classifier__max_leaf_nodes': 10},
#     {'classifier__max_depth': 5, 'classifier__max_leaf_nodes': 20},
#     {'classifier__max_depth': 5, 'classifier__max_leaf_nodes': 100},
#     {'classifier__max_depth': 25, 'classifier__max_leaf_nodes': 10},
#     {'classifier__max_depth': 25, 'classifier__max_leaf_nodes': 20},
#     {'classifier__max_depth': 25, 'classifier__max_leaf_nodes': 100}],
#    'split0_test_score': array([0.87458432, 0.87458432, 0.87458432, 0.8932304 , 0.89952494,
#           0.89952494, 0.8932304 , 0.92019002, 0.92470309]),
#    'split1_test_score': array([0.87292162, 0.87292162, 0.87292162, 0.88954869, 0.90415677,
#           0.90415677, 0.88954869, 0.91484561, 0.92529691]),
#    'split2_test_score': array([0.87826603, 0.87826603, 0.87826603, 0.89465558, 0.90095012,
#           0.90095012, 0.89465558, 0.92090261, 0.92707838]),
#    'split3_test_score': array([0.87850356, 0.87850356, 0.87850356, 0.89833729, 0.895962  ,
#           0.895962  , 0.89833729, 0.92078385, 0.92589074]),
#    'split4_test_score': array([0.87658867, 0.87658867, 0.87658867, 0.89499941, 0.9001069 ,
#           0.9001069 , 0.89499941, 0.91614206, 0.9249317 ]),
#    'mean_test_score': array([0.87617284, 0.87617284, 0.87617284, 0.89415428, 0.90014015,
#           0.90014015, 0.89415428, 0.91857283, 0.92558016]),
#    'std_test_score': array([0.00214851, 0.00214851, 0.00214851, 0.00284704, 0.00263157,
#           0.00263157, 0.00284704, 0.00255862, 0.00084984]),
#    'rank_test_score': array([7, 7, 7, 5, 3, 3, 5, 2, 1])}},
#  'RandomForestClassifier': {'best_params': {'classifier__max_depth': 50,
#    'classifier__max_leaf_nodes': 250,
#    'classifier__n_estimators': 300},
#   'best_score': 0.926957850964296,
#   'cv_results': {'mean_fit_time': array([ 3.79643235, 10.70672464, 17.64059238,  3.51762142, 10.49415441,
#           17.9019762 ,  3.59371333, 10.49284101, 18.1456419 ,  4.55740585,
#           14.54496198, 25.37385135,  6.11842165, 17.66273265, 28.09279079,
#            6.34593668, 17.76177816, 29.74127474,  4.80981674, 13.832442  ,
#           23.69465547,  6.02953053, 16.16653032, 27.6191494 ,  5.80206318,
#           17.34714208, 24.94173431]),
#    'std_fit_time': array([0.31804008, 0.40661085, 0.26838575, 0.0801343 , 0.0863413 ,
#           0.44717842, 0.1180409 , 0.23082772, 0.81516354, 0.30072312,
#           0.57388333, 0.65846854, 0.109254  , 0.67020655, 1.06276391,
#           0.51025192, 0.602461  , 0.78952762, 0.09303139, 0.46270197,
#           1.13330097, 0.41429214, 0.31258351, 0.67958222, 0.17863489,
#           0.44148847, 2.02146982]),
#    'mean_score_time': array([0.23467293, 0.68190842, 1.13568988, 0.23812351, 0.67523775,
#           1.17777715, 0.23416519, 0.69106932, 1.39071679, 0.26785007,
#           0.9156414 , 1.4418293 , 0.31680923, 0.96352057, 1.57383995,
#           0.37282834, 1.04090805, 1.73334661, 0.26566267, 0.91036611,
#           1.37455726, 0.34799852, 0.97280269, 1.60197086, 0.33887033,
#           1.03660231, 0.93650141]),
#    'std_score_time': array([0.00883903, 0.02213312, 0.02796167, 0.01085152, 0.02859866,
#           0.04177065, 0.01730366, 0.03002397, 0.11352848, 0.02191875,
#           0.09648247, 0.10388287, 0.0249458 , 0.02471655, 0.08329477,
#           0.03859071, 0.04861171, 0.1108396 , 0.02120464, 0.07320843,
#           0.03688917, 0.04463923, 0.04864776, 0.09954773, 0.01387984,
#           0.04014282, 0.16918348]),
#    'param_classifier__max_depth': masked_array(data=[3, 3, 3, 3, 3, 3, 3, 3, 3, 10, 10, 10, 10, 10, 10, 10,
#                       10, 10, 50, 50, 50, 50, 50, 50, 50, 50, 50],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__max_leaf_nodes': masked_array(data=[20, 20, 20, 100, 100, 100, 250, 250, 250, 20, 20, 20,
#                       100, 100, 100, 250, 250, 250, 20, 20, 20, 100, 100,
#                       100, 250, 250, 250],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__n_estimators': masked_array(data=[100, 300, 500, 100, 300, 500, 100, 300, 500, 100, 300,
#                       500, 100, 300, 500, 100, 300, 500, 100, 300, 500, 100,
#                       300, 500, 100, 300, 500],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False],
#           fill_value='?',
#                dtype=object),
#    'params': [{'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 3,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 10,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 20,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 100,
#      'classifier__n_estimators': 500},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 100},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 300},
#     {'classifier__max_depth': 50,
#      'classifier__max_leaf_nodes': 250,
#      'classifier__n_estimators': 500}],
#    'split0_test_score': array([0.88586698, 0.88741093, 0.88741093, 0.88586698, 0.88741093,
#           0.88741093, 0.88586698, 0.88741093, 0.88741093, 0.89988124,
#           0.9043943 , 0.90285036, 0.92232779, 0.92304038, 0.92304038,
#           0.92494062, 0.92565321, 0.9260095 , 0.90011876, 0.9043943 ,
#           0.90285036, 0.92315914, 0.92327791, 0.92327791, 0.92743468,
#           0.92755344, 0.92885986]),
#    'split1_test_score': array([0.88432304, 0.88539192, 0.88539192, 0.88432304, 0.88539192,
#           0.88539192, 0.88432304, 0.88539192, 0.88539192, 0.89904988,
#           0.90308789, 0.90225653, 0.91864608, 0.91983373, 0.91912114,
#           0.92351544, 0.92375297, 0.92315914, 0.89904988, 0.90308789,
#           0.90225653, 0.91828979, 0.92019002, 0.9195962 , 0.92339667,
#           0.92505938, 0.92505938]),
#    'split2_test_score': array([0.88752969, 0.88729216, 0.88729216, 0.88752969, 0.88729216,
#           0.88729216, 0.88752969, 0.88729216, 0.88729216, 0.90154394,
#           0.90486936, 0.90380048, 0.92470309, 0.92553444, 0.92517815,
#           0.9263658 , 0.92648456, 0.92672209, 0.90142518, 0.90463183,
#           0.90344418, 0.92541568, 0.92577197, 0.92529691, 0.9280285 ,
#           0.92755344, 0.92743468]),
#    'split3_test_score': array([0.89144893, 0.8932304 , 0.89073634, 0.89144893, 0.8932304 ,
#           0.89073634, 0.89144893, 0.8932304 , 0.89073634, 0.90534442,
#           0.90866983, 0.90570071, 0.92505938, 0.92517815, 0.92541568,
#           0.9283848 , 0.92862233, 0.92814727, 0.90534442, 0.90866983,
#           0.90570071, 0.92517815, 0.92577197, 0.92541568, 0.92957245,
#           0.92909739, 0.9283848 ]),
#    'split4_test_score': array([0.88739755, 0.88787267, 0.88704122, 0.88739755, 0.88787267,
#           0.88704122, 0.88739755, 0.88787267, 0.88704122, 0.90153225,
#           0.90378905, 0.90331393, 0.92148711, 0.92196223, 0.92160589,
#           0.92433781, 0.92374391, 0.92386269, 0.90153225, 0.90378905,
#           0.90355149, 0.92184345, 0.92184345, 0.92136833, 0.92576315,
#           0.9255256 , 0.92481292]),
#    'mean_test_score': array([0.88731324, 0.88823962, 0.88757451, 0.88731324, 0.88823962,
#           0.88757451, 0.88731324, 0.88823962, 0.88757451, 0.90147035,
#           0.90496209, 0.9035844 , 0.92244469, 0.92310979, 0.92287225,
#           0.92550889, 0.9256514 , 0.92558014, 0.9014941 , 0.90491458,
#           0.90356065, 0.92277724, 0.92337107, 0.92299101, 0.92683909,
#           0.92695785, 0.92691033]),
#    'std_test_score': array([0.00237448, 0.00263577, 0.00174079, 0.00237448, 0.00263577,
#           0.00174079, 0.00237448, 0.00263577, 0.00174079, 0.0021634 ,
#           0.00194767, 0.00117479, 0.00233654, 0.00210767, 0.00234474,
#           0.00171309, 0.00183102, 0.0018379 , 0.00213058, 0.00195224,
#           0.00116608, 0.0026031 , 0.00219043, 0.0022555 , 0.00210943,
#           0.00147937, 0.00167778]),
#    'rank_test_score': array([25, 19, 22, 25, 19, 22, 25, 19, 22, 18, 13, 15, 12,  8, 10,  6,  4,
#            5, 17, 14, 16, 11,  7,  9,  3,  1,  2])}},
#  'KNeighborsClassifier': {'best_params': {'classifier__n_neighbors': 30,
#    'classifier__weights': 'distance'},
#   'best_score': 0.9100216567039997,
#   'cv_results': {'mean_fit_time': array([0.4107872 , 0.38771653, 0.42236795, 0.45607662, 0.51511555,
#           0.56593466]),
#    'std_fit_time': array([0.01249914, 0.0151974 , 0.02629929, 0.06115648, 0.06145037,
#           0.05950246]),
#    'mean_score_time': array([14.51783271, 11.91901069, 13.84257345, 10.85274134, 13.79842949,
#            9.45229211]),
#    'std_score_time': array([0.22906315, 1.51868873, 0.49959945, 0.88521729, 0.50039319,
#           1.39833827]),
#    'param_classifier__n_neighbors': masked_array(data=[5, 5, 30, 30, 50, 50],
#                 mask=[False, False, False, False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_classifier__weights': masked_array(data=['uniform', 'distance', 'uniform', 'distance',
#                       'uniform', 'distance'],
#                 mask=[False, False, False, False, False, False],
#           fill_value='?',
#                dtype=object),
#    'params': [{'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'},
#     {'classifier__n_neighbors': 5, 'classifier__weights': 'distance'},
#     {'classifier__n_neighbors': 30, 'classifier__weights': 'uniform'},
#     {'classifier__n_neighbors': 30, 'classifier__weights': 'distance'},
#     {'classifier__n_neighbors': 50, 'classifier__weights': 'uniform'},
#     {'classifier__n_neighbors': 50, 'classifier__weights': 'distance'}],
#    'split0_test_score': array([0.89916865, 0.90059382, 0.89952494, 0.91045131, 0.89109264,
#           0.90831354]),
#    'split1_test_score': array([0.90320665, 0.90581948, 0.89619952, 0.90712589, 0.88764846,
#           0.90534442]),
#    'split2_test_score': array([0.90463183, 0.90605701, 0.89726841, 0.90902613, 0.89061758,
#           0.90736342]),
#    'split3_test_score': array([0.90855107, 0.90950119, 0.90178147, 0.91175772, 0.89465558,
#           0.91045131]),
#    'split4_test_score': array([0.90996555, 0.91032189, 0.90117591, 0.91174724, 0.89012947,
#           0.90996555]),
#    'mean_test_score': array([0.90510475, 0.90645868, 0.89919005, 0.91002166, 0.89082874,
#           0.90828765]),
#    'std_test_score': array([0.00386182, 0.00343941, 0.00216366, 0.00176367, 0.0022522 ,
#           0.00184468]),
#    'rank_test_score': array([4, 3, 5, 1, 6, 2])}}}

# %%
Models = [
    'XGBClassifier',
    'LogisticRegression',
    'DecisionTreeClassifier',
    'RandomForestClassifier',
    'KNeighborsClassifier']

Tabs = ['A', 'B', 'C', 'D', 'E']

op_table = pd.DataFrame(columns=['Model','Fit Time (seconds)','Predict Time (seconds)','Test Accuracy (Optimized)'])

for tab, Model in zip(Tabs, Models):
    tab_df = pd.DataFrame(results[Model]['cv_results'])
    num_entries = len(tab_df)  # Get the number of entries in cv_results
    for num in range(num_entries):
        if tab_df['rank_test_score'][num] == 1:
            fit_time = tab_df['mean_fit_time'][num]
            score_time = tab_df['mean_score_time'][num]
            Test_accuracy = tab_df['mean_test_score'][num]
            op_table = pd.concat([op_table,pd.DataFrame({'Model':[Model],'Fit Time (seconds)':[fit_time],
                                                         'Predict Time (seconds)':[score_time],'Test Accuracy (Optimized)':[Test_accuracy]})],ignore_index=True)

# %%
op_table
# Out:
#                     Model  Fit Time (seconds)  Predict Time (seconds)  \
# 0           XGBClassifier            2.628627                0.075001
# 1      LogisticRegression            0.317616                0.015778
# 2  DecisionTreeClassifier            0.132652                0.004092
# 3  RandomForestClassifier           17.347142                1.036602
# 4    KNeighborsClassifier            0.456077               10.852741
#
#    Test Accuracy (Optimized)
# 0                   0.927528
# 1                   0.830138
# 2                   0.925580
# 3                   0.926958
# 4                   0.910022

# %%
compare_table = op_table.merge(result_table_sorted[['Model','Test Accuracy']],how='inner',on='Model')

# %%
compare_table
# Out:
#                     Model  Fit Time (seconds)  Predict Time (seconds)  \
# 0           XGBClassifier            2.628627                0.075001
# 1      LogisticRegression            0.317616                0.015778
# 2  DecisionTreeClassifier            0.132652                0.004092
# 3  RandomForestClassifier           17.347142                1.036602
# 4    KNeighborsClassifier            0.456077               10.852741
#
#    Test Accuracy (Optimized)  Test Accuracy
# 0                   0.927528       0.925271
# 1                   0.830138       0.830281
# 2                   0.925580       0.920164
# 3                   0.926958       0.924107
# 4                   0.910022       0.906387

# %%
compare_table['% Difference'] = (compare_table['Test Accuracy (Optimized)'] - compare_table['Test Accuracy'])*100

# %%
compare_table['% Difference'] = compare_table['% Difference'].map('{:.2f}'.format)

# %%
compare_table = compare_table.sort_values(by='Test Accuracy (Optimized)', ascending=False)

# %%
compare_table
# Out:
#                     Model  Fit Time (seconds)  Predict Time (seconds)  \
# 0           XGBClassifier            2.628627                0.075001
# 3  RandomForestClassifier           17.347142                1.036602
# 2  DecisionTreeClassifier            0.132652                0.004092
# 4    KNeighborsClassifier            0.456077               10.852741
# 1      LogisticRegression            0.317616                0.015778
#
#    Test Accuracy (Optimized)  Test Accuracy % Difference
# 0                   0.927528       0.925271         0.23
# 3                   0.926958       0.924107         0.29
# 2                   0.925580       0.920164         0.54
# 4                   0.910022       0.906387         0.36
# 1                   0.830138       0.830281        -0.01

# %%
plt.subplot(1,2,1)
plt.barh(width=compare_table['Test Accuracy (Optimized)'],y=compare_table['Model'], alpha=0.3, height=0.3, label='Test Accuracy (Optimized)')
plt.barh(width=compare_table['Test Accuracy'],y=compare_table['Model'],align='edge', alpha=0.3, height=0.3, label='Test Accuracy')
plt.legend(loc='upper left')
plt.xlabel('Accuracy - higher is better')
plt.subplot(1,2,2)
plt.plot(compare_table['Fit Time (seconds)'],compare_table['Model'], marker='o', label='Fit Time')
plt.plot(compare_table['Predict Time (seconds)'],compare_table['Model'], marker='x', label='Predict Time')
plt.legend()
plt.xlabel('Time - lower is better')
plt.subplots_adjust(wspace=0.5, right=2)
plt.show()

# %% [markdown]
# <font color="blue">The hyperparameters optimization gives almost no improvement, with the difference of accuracy bwtween before and after optimization is less than 1%.
#
# <font color="blue">The top 3 models have similar test acuracy ranging from 92.6% to 92.8%. Decision Tree model has the highest % improvement after hyperparameters optimization, around 0.5% increase.
#
# <font color="blue">In terms of time taken for model training and prediction, Random Forest took the longest time while Decision Time is the fastest model among the 5 models.
#
# <font color="blue">In considering the difference of accuracy between top 3 models is insignificant, we choose Decision Tree model that requires least computation cost as our best model.

# %% [markdown]
# # Final Model Evaluation

# %%
#best parameters for Decision Tree model
results['DecisionTreeClassifier']['best_params']
# Out:
# {'classifier__max_depth': 25, 'classifier__max_leaf_nodes': 100}

# %%
dt_op = DecisionTreeClassifier(max_depth=5, max_leaf_nodes=20, random_state=SEED)
dt_op.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, max_leaf_nodes=20, random_state=42)

# %%
print('Training Accuracy: ',dt_op.score(x_train,y_train), '\nTest Accuracy: ', dt_op.score(x_test,y_test))
# Out:
# Training Accuracy:  0.9008765053801753
# Test Accuracy:  0.9011805132184226

# %%
y_pred = dt_op.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
dfConfu = confusion_matrix(y_test, y_pred)

# %%
print(dfConfu)
# Out:
# [[8521  713]
#  [1070 7739]]

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(dfConfu, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['No Disease', 'Disease'],
            yticklabels=['No Disease', 'Disease'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
report_dt = classification_report(y_test, y_pred, target_names=['No Disease','Disease'])

# %%
print(report_dt)
# Out:
#               precision    recall  f1-score   support
#
#   No Disease       0.89      0.92      0.91      9234
#      Disease       0.92      0.88      0.90      8809
#
#     accuracy                           0.90     18043
#    macro avg       0.90      0.90      0.90     18043
# weighted avg       0.90      0.90      0.90     18043

# %% [markdown]
# <font color="blue">The final Decision Tree model gives a test accuracy of 90.1% using Test Data.
#
# <font color="blue">Out of the cases predicted with Heart Disease, 92% are actually diagnosed with Heart Disease.
# Out of the cases predicted with no Heart Disease, 89% are actually diagnosed with no Heart Disease.
#
# <font color="blue">From all cases with Heart Disease, 88% are predicted correctly.
# From all cases with no Heart Disease, 92% are predicted correctly.

# %%
feature_importances = dt_op.feature_importances_
feature_names = x.columns
sorted_indices = (-feature_importances).argsort()
sorted_feature_names = [feature_names[i] for i in sorted_indices]
sorted_feature_importances = [feature_importances[i] for i in sorted_indices]


plt.figure(figsize=(10, 6))
plt.bar(sorted_feature_names, sorted_feature_importances, align='center')
plt.xlabel('Features')
plt.ylabel('Importance Score')
plt.title('Feature Importance of Decision Tree')
plt.show()

# %% [markdown]
# <font color="blue">From above chart, the top four most important features in predicting Heart Disease are clusters, mean arterial pressure, age, and BMI.

# %% [markdown]
# # Conclusion and Recommendation

# %% [markdown]
# Overall the model test score is sufficiently high for an efficient prediction. There could be few possible reasons the model cannot reach 100%:
#
# 1) The data given is likely to have been manually adjusted to give a sample population of Disease almost same as No Disease. In real world, the population with heart disease is about 5-10% out of the total population. In contrast, 50% of the records in the given data has heart disease. This adjustment might have certain impacts to some features in correlation to our prediction target.
#
# 2) Some features such as cholesterol level and glucose level are given in categories instead of numerical data, causing loss of details in data. Numerical data gives more details and may give higher correlation to our prediction target leading to an improvement of model accuracy.
#
# 3) The given features may not be sufficient to give a better prediction. Additional features might be needed.
#
# Some recommendations to improve the model are:
#
# 1) Include more features such as 'Family History' and 'Presence of Diabetes'
#
# 2) To look for original data that has not been adjusted and features like cholesterol level and glucose level are in numerical form.
